# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/inputs/submission.csv')
data.head()
# Out:
#             Timestamp             Email Address      Full Name  \
# 0   1/20/2026 0:59:58   cgupta2_be23@thapar.edu   Chirag Gupta
# 1   1/20/2026 1:01:28   cgupta2_be23@thapar.edu   Chirag Gupta
# 2   1/20/2026 1:03:00   cgupta2_be23@thapar.edu  Chirag Gupta
# 3   1/20/2026 1:04:41   cgupta2_be23@thapar.edu   Chirag Gupta
# 4  1/19/2026 11:51:21  nsharma3_be23@thapar.edu   Nihar Sharma
#
#    Roll Number of the Student  \
# 0                   102303003
# 1                   102303003
# 2                   102303003
# 3                   102303003
# 4                   102303012
#
#                 Coursera completion certificate link  \
# 0  https://www.coursera.org/account/accomplishmen...
# 1  https://www.coursera.org/account/accomplishmen...
# 2  https://www.coursera.org/account/accomplishmen...
# 3  https://www.coursera.org/account/accomplishmen...
# 4  https://coursera.org/share/e8e72de68d980893288...
#
# ...

# %%
from tools.coursera_tool import verify_coursera_certificate

# ===============================
# TEST INPUT
# ===============================
coursera_url = input("Enter Coursera certificate URL: ")
student_name = input("Enter expected student name: ")

print("\n--- STARTING COURSERA PERCEPTION TEST ---\n")

result = verify_coursera_certificate(coursera_url, student_name)

print("Certificate Status:")
print(result.get("Cert_Status", "Unknown"))

print("\n--- RAW EXTRACTED TEXT (START) ---\n")
print(result.get("raw_text", "No text extracted"))
print("\n--- RAW EXTRACTED TEXT (END) ---\n")

print("✅ Sensor test complete.")
# Out:
# --- STARTING COURSERA PERCEPTION TEST ---
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 11
#       7 student_name = input("Enter expected student name: ")
#       9 print("\n--- STARTING COURSERA PERCEPTION TEST ---\n")
# ---> 11 result = verify_coursera_certificate(coursera_url, student_name)
#      13 print("Certificate Status:")
#      14 print(result.get("Cert_Status", "Unknown"))
#
# File c:\Users\bhati\OneDrive\Documents\6th Sem\6th Sem\DS1\agentic_evaluator\tools\coursera_tool.py:7, in verify_coursera_certificate(url, expected_name)
#       3 def verify_coursera_certificate(url, expected_name):
#       4     """
#       5     Sensor: Extracts all visible text from a Coursera certificate page.
#       6     """
# ----> 7     with sync_playwright() as p:
#       8         browser = p.chromium.launch(headless=True)
# ...
